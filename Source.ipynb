# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
from scipy.stats import sem
import numpy as np
import hvplot.pandas

# %%
# Assign data files
events = "athlete_events.csv"
region = "noc_regions.csv"
# Read the data
events_data = pd.read_csv(events)
region_data = pd.read_csv(region)
#events_data.head()
#region_data.head()
#Combine the data into a single DataFrame
Olympics_df = pd.merge(events_data,region_data, how ="left", on ='NOC')
Olympics_df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
olympics_fdf = Olympics_df[['ID', 'Name', 'Sex', 'Age','Height','Weight','Team','Games','Year','Season','City','Sport','Medal','region']]
olympics_fdf
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team        Games  Year  Season            City  \
# 0                China  1992 Summer  1992  Summer       Barcelona
# 1                China  2012 Summer  2012  Summer          London
# 2              Denmark  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  1900 Summer  1900  Summer           Paris
# 4          Netherlands  1988 Winter  1988  Winter         Calgary
# ...                ...          ...   ...     ...             ...
# 271111        Poland-1  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  2014 Winter  2014  Winter           Sochi
# 271113          Poland  2014 Winter  2014  Winter           Sochi
# 271114          Poland  1998 Winter  1998  Winter          Nagano
# 271115          Poland  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport Medal       region
# 0          Basketball   NaN        China
# 1                Judo   NaN        China
# 2            Football   NaN      Denmark
# 3          Tug-Of-War  Gold      Denmark
# 4       Speed Skating   NaN  Netherlands
# ...               ...   ...          ...
# 271111           Luge   NaN       Poland
# 271112    Ski Jumping   NaN       Poland
# 271113    Ski Jumping   NaN       Poland
# 271114      Bobsleigh   NaN       Poland
# 271115      Bobsleigh   NaN       Poland
#
# [271116 rows x 14 columns]

# %%
olympics_region=olympics_fdf.loc[olympics_fdf["Medal"]=="Gold"]
olympics_region=olympics_region.loc[olympics_fdf["Medal"]!="NaN"]
olympics_region2=olympics_region.groupby("region")
olympics_region2.head()
# Out:
#             ID                                   Name Sex   Age  Height  \
# 3            4                   Edgar Lindenau Aabye   M  34.0     NaN
# 42          17                Paavo Johannes Aaltonen   M  28.0   175.0
# 44          17                Paavo Johannes Aaltonen   M  28.0   175.0
# 48          17                Paavo Johannes Aaltonen   M  28.0   175.0
# 60          20                     Kjetil Andr Aamodt   M  20.0   176.0
# ...        ...                                    ...  ..   ...     ...
# 246669  123513               Mara Isabel Urrutia Ocor   F  35.0   170.0
# 250501  125468               Edwin Gonzalo Vsquez Cam   M  25.0     NaN
# 252586  126491                          Igors Vihrovs   M  22.0   165.0
# 259005  129665  Hannelore "Hanni" Wenzel (-Weirather)   F  23.0   165.0
# 259006  129665  Hannelore "Hanni" Wenzel (-Weirather)   F  23.0   165.0
#
#         Weight            Team        Games  Year  Season         City  \
# 3          NaN  Denmark/Sweden  1900 Summer  1900  Summer        Paris
# 42        64.0         Finland  1948 Summer  1948  Summer       London
# 44        64.0         Finland  1948 Summer  1948  Summer       London
# 48        64.0         Finland  1948 Summer  1948  Summer       London
# 60        85.0          Norway  1992 Winter  1992  Winter  Albertville
# ...        ...             ...          ...   ...     ...          ...
# 246669    78.0        Colombia  2000 Summer  2000  Summer       Sydney
# 250501     NaN            Peru  1948 Summer  1948  Summer       London
# 252586    62.0          Latvia  2000 Summer  2000  Summer       Sydney
# 259005    57.0   Liechtenstein  1980 Winter  1980  Winter  Lake Placid
# 259006    57.0   Liechtenstein  1980 Winter  1980  Winter  Lake Placid
#
#                 Sport Medal         region
# 3          Tug-Of-War  Gold        Denmark
# 42         Gymnastics  Gold        Finland
# 44         Gymnastics  Gold        Finland
# 48         Gymnastics  Gold        Finland
# 60      Alpine Skiing  Gold         Norway
# ...               ...   ...            ...
# 246669  Weightlifting  Gold       Colombia
# 250501       Shooting  Gold           Peru
# 252586     Gymnastics  Gold         Latvia
# 259005  Alpine Skiing  Gold  Liechtenstein
# 259006  Alpine Skiing  Gold  Liechtenstein
#
# [384 rows x 14 columns]

# %%
olympics_age=olympics_fdf[olympics_fdf["Age"] !='N/A']
olympics_age.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#          Games  Year  Season       City          Sport Medal       region
# 0  1992 Summer  1992  Summer  Barcelona     Basketball   NaN        China
# 1  2012 Summer  2012  Summer     London           Judo   NaN        China
# 2  1920 Summer  1920  Summer  Antwerpen       Football   NaN      Denmark
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War  Gold      Denmark
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating   NaN  Netherlands

# %%
olympics_age.dropna(subset=['Medal'],inplace=True)
olympics_age.head()
# Out:
#     ID                      Name Sex   Age  Height  Weight            Team  \
# 3    4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 37  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 38  15      Arvo Ossian Aaltonen   M  30.0     NaN     NaN         Finland
# 40  16  Juhamatti Tapio Aaltonen   M  28.0   184.0    85.0         Finland
# 41  17   Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
#
#           Games  Year  Season       City       Sport   Medal   region
# 3   1900 Summer  1900  Summer      Paris  Tug-Of-War    Gold  Denmark
# 37  1920 Summer  1920  Summer  Antwerpen    Swimming  Bronze  Finland
# 38  1920 Summer  1920  Summer  Antwerpen    Swimming  Bronze  Finland
# 40  2014 Winter  2014  Winter      Sochi  Ice Hockey  Bronze  Finland
# 41  1948 Summer  1948  Summer     London  Gymnastics  Bronze  Finland

# %%
region=olympics_age.groupby('region').Age.max()
region.tail()
# Out:
# region
# Venezuela             52.0
# Vietnam               41.0
# Virgin Islands, US    27.0
# Zambia                27.0
# Zimbabwe              35.0
# Name: Age, dtype: float64

# %%
agg=olympics_age.groupby('region').Age.agg(['count','max','min','mean'])
agg
# Out:
#                     count   max   min       mean
# region
# Afghanistan             2  25.0  21.0  23.000000
# Algeria                17  29.0  19.0  24.117647
# Argentina             274  56.0  18.0  26.423358
# Armenia                16  28.0  19.0  23.375000
# Australia            1344  61.0  14.0  24.802827
# ...                   ...   ...   ...        ...
# Venezuela              15  52.0  19.0  24.200000
# Vietnam                 4  41.0  23.0  32.750000
# Virgin Islands, US      1  27.0  27.0  27.000000
# Zambia                  1  27.0  27.0  27.000000
# Zimbabwe               22  35.0  20.0  25.363636
#
# [136 rows x 4 columns]

# %%
regiongold=olympics_fdf.groupby('region').Medal.count()
regiongold
# Out:
# region
# Afghanistan                 2
# Albania                     0
# Algeria                    17
# American Samoa              0
# Andorra                     0
#                            ..
# Virgin Islands, British     0
# Virgin Islands, US          1
# Yemen                       0
# Zambia                      2
# Zimbabwe                   22
# Name: Medal, Length: 205, dtype: int64

# %%
boxplot = olympics_age.hvplot.box(y='Age', by='Medal', c='gold', height=450, width=450, legend=False)
boxplot
# Out:
# :BoxWhisker   [Medal]   (Age)

# %%
olympicscoordinates = "Lat_Long.csv"
df_loc = pd.read_csv(olympicscoordinates)
olympiclocations = pd.merge(Olympics_df,df_loc, how ="left", on ='region')
olympiclocations.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes country  \
# 0       Basketball Men's Basketball   NaN        China   NaN      CN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN      CN
# 2           Football Men's Football   NaN      Denmark   NaN      DK
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN      DK
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN      NL
#
#     latitude   longitude
# 0  35.861660  104.195397
# 1  35.861660  104.195397
# 2  56.263920    9.501785
# 3  56.263920    9.501785
# 4  52.132633    5.291266

# %%
olympiclocations.dropna(subset=['Age','Medal'],inplace=True)
olympics_map1 = olympiclocations[['Age','Medal','region','latitude','longitude']]
nz=olympics_map1[olympics_map1["region"] =='New Zealand']
nz
# Out:
#          Age   Medal       region   latitude   longitude
# 1238    27.0    Gold  New Zealand -40.900557  174.885971
# 1527    23.0    Gold  New Zealand -40.900557  174.885971
# 1528    27.0    Gold  New Zealand -40.900557  174.885971
# 1529    31.0  Silver  New Zealand -40.900557  174.885971
# 4317    26.0    Gold  New Zealand -40.900557  174.885971
# ...      ...     ...          ...        ...         ...
# 261251  33.0  Bronze  New Zealand -40.900557  174.885971
# 261533  23.0    Gold  New Zealand -40.900557  174.885971
# 261534  27.0  Bronze  New Zealand -40.900557  174.885971
# 262850  25.0  Silver  New Zealand -40.900557  174.885971
# 263207  26.0  Bronze  New Zealand -40.900557  174.885971
#
# [228 rows x 5 columns]

# %%
nozeroes = olympics_map1.loc[(olympics_map1!=0).any(axis=1)]
nozeroes
# Out:
#          Age   Medal   region   latitude   longitude
# 3       34.0    Gold  Denmark  56.263920    9.501785
# 37      30.0  Bronze  Finland  61.924110   25.748151
# 38      30.0  Bronze  Finland  61.924110   25.748151
# 40      28.0  Bronze  Finland  61.924110   25.748151
# 41      28.0  Bronze  Finland  61.924110   25.748151
# ...      ...     ...      ...        ...         ...
# 271078  25.0  Silver   Russia  61.524010  105.318756
# 271080  33.0  Bronze   Russia  61.524010  105.318756
# 271082  28.0  Bronze   Poland  51.919438   19.145136
# 271102  19.0  Bronze   Russia  61.524010  105.318756
# 271103  23.0  Silver   Russia  61.524010  105.318756
#
# [39051 rows x 5 columns]

# %%
olympics_map1['Gold']=0
olympics_map1.loc[olympics_map1['Medal']=="Gold","Gold"]=1

# %%
newolympics_mapdf=olympics_map1.copy()
newolympics_mapdf['sizeMedal']=1
newolympics_mapdf.loc[olympics_map1['Medal']=="Gold","sizeMedal"]=10
newolympics_mapdf.loc[olympics_map1['Medal']=="Silver","sizeMedal"]=6
newolympics_mapdf.loc[olympics_map1['Medal']=="Bronze","sizeMedal"]=3
newolympics_mapdf
# Out:
#          Age   Medal   region   latitude   longitude  sizeMedal
# 3       34.0    Gold  Denmark  56.263920    9.501785         10
# 37      30.0  Bronze  Finland  61.924110   25.748151          3
# 38      30.0  Bronze  Finland  61.924110   25.748151          3
# 40      28.0  Bronze  Finland  61.924110   25.748151          3
# 41      28.0  Bronze  Finland  61.924110   25.748151          3
# ...      ...     ...      ...        ...         ...        ...
# 271078  25.0  Silver   Russia  61.524010  105.318756          6
# 271080  33.0  Bronze   Russia  61.524010  105.318756          3
# 271082  28.0  Bronze   Poland  51.919438   19.145136          3
# 271102  19.0  Bronze   Russia  61.524010  105.318756          3
# 271103  23.0  Silver   Russia  61.524010  105.318756          6
#
# [39051 rows x 6 columns]

# %%
newolympics_mapdf=newolympics_mapdf.loc[newolympics_mapdf["sizeMedal"]>1]
newolympics_mapdf
# Out:
#          Age   Medal   region   latitude   longitude  sizeMedal
# 3       34.0    Gold  Denmark  56.263920    9.501785         10
# 37      30.0  Bronze  Finland  61.924110   25.748151          3
# 38      30.0  Bronze  Finland  61.924110   25.748151          3
# 40      28.0  Bronze  Finland  61.924110   25.748151          3
# 41      28.0  Bronze  Finland  61.924110   25.748151          3
# ...      ...     ...      ...        ...         ...        ...
# 271078  25.0  Silver   Russia  61.524010  105.318756          6
# 271080  33.0  Bronze   Russia  61.524010  105.318756          3
# 271082  28.0  Bronze   Poland  51.919438   19.145136          3
# 271102  19.0  Bronze   Russia  61.524010  105.318756          3
# 271103  23.0  Silver   Russia  61.524010  105.318756          6
#
# [39051 rows x 6 columns]

# %%
newolympics_mapdf.dtypes
# Out:
# Age          float64
# Medal         object
# region        object
# latitude     float64
# longitude    float64
# sizeMedal      int64
# dtype: object

# %%
newolympics_mapdf['Medal']=newolympics_mapdf['Medal'].astype(str)

# %%
newolympics_mapdf.dtypes
# Out:
# Age          float64
# Medal         object
# region        object
# latitude     float64
# longitude    float64
# sizeMedal      int64
# dtype: object

# %%
check=olympics_map1.loc[olympics_map1['Age'] <= 0]
olympics_map1.dtypes
# Out:
# Age          float64
# Medal         object
# region        object
# latitude     float64
# longitude    float64
# dtype: object

# %%
newolympics_mapdf
# Out:
#          Age   Medal   region   latitude   longitude  sizeMedal
# 3       34.0    Gold  Denmark  56.263920    9.501785         10
# 37      30.0  Bronze  Finland  61.924110   25.748151          3
# 38      30.0  Bronze  Finland  61.924110   25.748151          3
# 40      28.0  Bronze  Finland  61.924110   25.748151          3
# 41      28.0  Bronze  Finland  61.924110   25.748151          3
# ...      ...     ...      ...        ...         ...        ...
# 271078  25.0  Silver   Russia  61.524010  105.318756          6
# 271080  33.0  Bronze   Russia  61.524010  105.318756          3
# 271082  28.0  Bronze   Poland  51.919438   19.145136          3
# 271102  19.0  Bronze   Russia  61.524010  105.318756          3
# 271103  23.0  Silver   Russia  61.524010  105.318756          6
#
# [39051 rows x 6 columns]

# %%
map_plot_2=newolympics_mapdf.hvplot.points(
    'longitude',
    'latitude',
    geo = True,
    tiles = "EsriImagery",
    color="sizeMedal",
    frame_width = 700,
    frame_height = 500,
    scale = .5)
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]   (sizeMedal)

# %%
map_plot_1=olympics_map1.hvplot.points(
    'longitude',
    'latitude',
    geo = True,
    tiles = "EsriImagery",
    scale = 0.5)
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [longitude,latitude]

# %%
sampleset = olympics_age['region']==

# %%
YoungestBronze=olympics_age.loc[olympics_age['Medal']=='Bronze'].Age.min()
YoungestBronze1=olympics_age.loc[olympics_age['Name']==YoungestBronze]
YoungestBronze1
# Out:
# Empty DataFrame
# Columns: [ID, Name, Sex, Age, Height, Weight, Team, Games, Year, Season, City, Sport, Medal, region]
# Index: []

# %%
#olympics_age.to_csv('olympic_merged.csv')

# %%
just_gold = olympics_age.loc[olympics_age['Medal'] == "Gold"]
just_gold.head()
just_gold.count()
# Out:
# ID        13372
# Name      13372
# Sex       13372
# Age       13224
# Height    10539
# Weight    10254
# Team      13372
# Games     13372
# Year      13372
# Season    13372
# City      13372
# Sport     13372
# Medal     13372
# region    13371
# dtype: int64

# %%
olympics_age.count()
# Out:
# ID        271116
# Name      271116
# Sex       271116
# Age       261642
# Height    210945
# Weight    208241
# Team      271116
# Games     271116
# Year      271116
# Season    271116
# City      271116
# Sport     271116
# Medal      39783
# region    270746
# dtype: int64
